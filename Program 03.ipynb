# %%
def main():
    sets = 0
    
    def introduction():
        print('This function will calculate the average value of three integers entered by user, the function will end if you enter the satanic 666')
        print('The user is Induranga Jayewardene')
    introduction()
    
    x = int(input('Enter a value to start the loop; Enter 666 to exit: '))
    while x != 666:
        
        print('Enter three integer values')
        X = int(input('Enter integer one:'))
        Y = int(input('Enter integer two:'))
        Z = int(input('Enter integer three:'))
        
        print(f'The three original integers are: {X}, {Y}, {Z}')

        def findaverage():
            P = (X+Y+Z)/3 
            D = "{:.3f}".format(P)
            return D
        findaverage()

        print(f'The average is: {findaverage()}')
        D = float(findaverage())

        def comparetoavg():
            num = 0
            if X > D:
                print(f'{X} is above the average')
            if X < D:
                print(f'{X} is below the average')
            if X == D:
                num+=1
                print(f'{X} is equal to average')
            if Y > D:
                print(f'{Y} is above the average')
            if Y < D:
                print(f'{Y} is below the average')
            if Y == D:
                num +=1
                print(f'{Y} is equal to average')
            if Z > D:
                print(f'{Z} is above the average')
            if Z < D:
                print(f'{Z} is below the average')
            if Z == D:
                num+=1
                print(f'{Z} is equal to average')
            print(f'{num} values are equal to the average' + '\n')
        comparetoavg()
        
        sets += 1
        x = int(input('Enter a number to continue and 666 to exit: '))

    print(f'{sets} of sets of three data values were entered and processed')
    
main()
# Out:
# This function will calculate the average value of three integers entered by user, it will end the function if you enter 666
# The user is Induranga Jayewardene
# Enter a value to start the loop; Enter 666 to exit: 1
# Enter three integer values
# Enter integer one:5
# Enter integer two:7
# Enter integer three:6
# The three original integers are: 5, 7, 6
# The average is: 6.000
# 5 is below the average
# 7 is above the average
# 6 is equal to average
# 1 values are equal to the average
#
# Enter a number to continue and 666 to exit: 1
# Enter three integer values
# Enter integer one:-5
# Enter integer two:6
# Enter integer three:-8
# The three original integers are: -5, 6, -8
# The average is: -2.333
# -5 is below the average
# 6 is above the average
# -8 is below the average
# 0 values are equal to the average
#
# Enter a number to continue and 666 to exit: 1
# Enter three integer values
# Enter integer one:7
# Enter integer two:7
# Enter integer three:7
# The three original integers are: 7, 7, 7
# The average is: 7.000
# 7 is equal to average
# 7 is equal to average
# 7 is equal to average
# 3 values are equal to the average
#
# Enter a number to continue and 666 to exit: 666
# 3 of sets of three data values were entered and processed

# %%
numbers.append(X)
numbers.append(Y)
numbers.append(Z)
